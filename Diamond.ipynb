# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamond=pd.read_csv("C:\\Users\\user\\diamonds.csv")

# %%
diamond.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
carat=diamond["carat"].value_counts().head(10)

# %%
diamond=diamond.drop(["Unnamed: 0"],axis=1)

# %%
diamond.sort_values(by=["color"]).value_counts()
# Out:
# carat  cut      color  clarity  depth  table  price  x     y     z
# 0.79   Ideal    G      SI1      62.3   57.0   2898   5.90  5.85  3.66    5
# 1.00   Premium  H      SI2      61.0   57.0   4032   6.51  6.40  3.94    2
# 1.51   Ideal    G      SI1      61.6   56.0   8283   7.34  7.25  4.50    2
# 1.23   Ideal    I      SI2      62.3   55.0   4773   6.85  6.82  4.26    2
# 1.80   Ideal    H      VS1      62.3   56.0   15105  7.79  7.76  4.84    2
#                                                                         ..
# 1.00   Premium  G      VS2      62.9   56.0   5806   6.42  6.27  3.99    1
#                                 62.3   58.0   5242   6.35  6.29  3.94    1
#                                 62.2   58.0   6048   6.54  6.49  3.94    1
#                                 62.1   58.0   5242   6.43  6.39  3.98    1
# 0.20   Ideal    D      VS2      61.5   57.0   367    3.81  3.77  2.33    1
# Length: 53794, dtype: int64

# %%
diamond.describe
# Out:
# <bound method NDFrame.describe of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
diamond.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamond["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
diamond["cut"].value_counts().keys()
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
plt.figure(figsize=(7,7))
plt.pie(list(diamond["cut"].value_counts()),labels=diamond["cut"].value_counts().keys(),autopct="%0.1ff%%")
plt.show()

# %%
table=diamond["table"].value_counts().head()

# %%
table_keys=diamond["table"].value_counts().head().keys()

# %%
plt.barh(table_keys,table,color="green")
plt.title="Tables of Diamonds"
plt.ylabel("Table")
plt.xlabel("no. of Daimonds")
plt.show()

# %%
price=diamond["price"].value_counts()

# %%
price
# Out:
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 13550      1
# 13014      1
# 6811       1
# 5354       1
# 11600      1
# Name: price, Length: 11602, dtype: int64

# %%
price_tags=diamond["price"].value_counts().keys

# %%
sns.barplot(x="clarity",y="price",data=diamond)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.distplot(diamond["price"],hist=True,color="Purple")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(7,7))
sns.displot(diamond["price"],kde=False,bins=10)
plt.show()

# %%
sns.distplot(diamond["depth"],bins=20,color="g")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,8))
plt.pie(carat,labels=carat.keys()[0:10],autopct="%0.1ff%%")
plt.show()

# %%
sns.jointplot(x="carat",y="price",data=diamond,kind="scatter")
plt.show()

# %%
sns.set_style('darkgrid')

# %%
sns.pairplot(diamond);
